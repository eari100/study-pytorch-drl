# %% [markdown]
# 3.4 Q러닝 구현

# %%
# 구현에 사용할 패키지 임포트
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gymnasium as gym

# %%
# 애니메이션을 만드는 함수
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)

    anim.save('movie_cartpole1.gif')  # 애니메이션을 저장하는 부분
    display(display_animation(anim, default_mode='loop'))

# %%
# 상수 정의
ENV = 'CartPole-v1' # 태스크 이름
NUM_DIZITIZED = 6 # 각 상태를 이산변수로 변활할 구간 수
GAMMA = 0.99 # 시간할인율
ETA = 0.5 # 학습률
MAX_STEPS = 200 # 1에피소드 당 최대 단계 수
NUM_EPISODES = 1000 # 최대 에피소드 수

# %%
class Agent:
    '''CartPole 에이전트 역할을 할 클랙스, 봉 달린 수레이다'''
    
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions) # 에이전트가 행동을 결정하는 두뇌 역할
        
    def update_Q_function(self, observation, action, reward, observation_next):
        '''Q함수 수정'''
        self.brain.update_Q_table(observation, action, reward, observation_next)
        
    def get_action(self, observation, step):
        '''행동 결정'''
        action = self.brain.decide_action(observation, step)
        return action

# %%
class Brain:
    '''에이전트의 두뇌 역할을 하는 클랙스, Q러닝을 실제 수행'''
    
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions # 행동의 가짓수(왼쪽, 오른쪽)를 구함
        
        # Q테이블을 생성. 줄 수는 상태를 구간수^4(4는 변수의 수)가지 값 중 하나로 변환한 값, 열 수는 행동의 가짓 수
        self.q_table = np.random.uniform(low=0, high=1, size=(NUM_DIZITIZED**num_states, num_actions))
        
    def bins(self, clip_min, clip_max, num):
        '''관측된 상태(연속값)를 이산변수로 변환하는 구간을 계산'''
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]
    
    def digitize_state(self, observation):
        '''관측된 상태 observation을 이산변수로 변환'''
        if isinstance(observation, tuple):
            obs_array = observation[0]
        elif isinstance(observation, np.ndarray):
            obs_array = observation
        else:
            raise ValueError("Unsupported observation type")
        
         # 변수 추출
        cart_pos, cart_v, pole_angle, pole_v = obs_array
        
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))
        ]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])
    
    def update_Q_table(self, observation, action, reward, observation_next):
        '''Q러닝으로 Q테이블 수정'''
        state = self.digitize_state(observation) # 상태를 이산변수로 변환
        state_next = self.digitize_state(observation_next) # 다음 상태를 이산변수로 변환
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = (self.q_table[state, action] 
                                       + ETA * (reward + GAMMA * Max_Q_next - self.q_table[state, action]))
    
    def decide_action(self, observation, episode):
        '''ε-greedy 알고리즘을 적용하여 서서히 최적행동의 비중을 늘림'''
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))
        
        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions) # 0, 1 두 가지 행동 중 하나를 무작위로 선택
        return action

# %%
class Environment:
    '''CartPole을 실행하는 환경 역할을 하는 클래스'''
    
    def __init__(self):
        self.env = gym.make(ENV, render_mode='human') # 실행할 태스크를 설정
        num_states = self.env.observation_space.shape[0]
        num_actions = self.env.action_space.n # 가능한 행동 수를 구함
        self.agent = Agent(num_states, num_actions) # 에이전트 객체 생성
        
    def run(self):
        '''실행'''
        complete_episodes = 0 # 성공한 (195 이상 버틴) 에피소드 수
        is_episode_final = False # 마지막 에피소드 여부
        frames = [] # 애니메이션을 만드는데 사용할 이미지를 저장하는 변수
        
        for episode in range(NUM_EPISODES):
            observation = self.env.reset() # 환경 초기화
            
            for step in range(MAX_STEPS): # 1 에피소드에 해당하는 반복
                
                if is_episode_final is True: # 마지막 에피소드면 frames에 각 단계의 이미지를 저장
                    frames.append(self.env.render())
                    
                # 행동을 선택
                action = self.agent.get_action(observation, episode)
                    
                # 행동 a_t를 실행하여 s_{t+1}, r_{t+1}을 계산
                observation_next, _, terminated, _, _ = self.env.step(action) # reward, info는 사용하지 않으므로 _로 처리함
                
                # 보상을 부여
                if terminated: # 200단계를 넘어서거나 일정 각도 이상 기울면 terminated 의 값이 True가 됨
                    if step < 195:
                        reward = -1  # 봉이 쓰러지면 페널티로 보상 -1 부여
                        complete_episodes = 0 # 195단계 이상 버티면 해당 에피소드를 성공 처리
                    else:
                        reward = 1 # 쓰러지지 않고 에피소드를 끝내면 보상 1 부여
                        complete_episodes += 1 # 에피소드 연속 성공 기록을 업데이트
                else:
                    reward = 0 # 에피소드 중에는 보상이 0
                
                # 다음 단계의 상태 observation_next로 Q함수를 수정
                self.agent.update_Q_function(observation, action, reward, observation_next)
                
                # 다음 단계 상태 관측
                observation = observation_next
                
                # 에피소드 마무리
                if terminated:
                    print('{0} Episode: Finished after {1} times steps'.format(episode, step+1) )
                    break
                    
                if is_episode_final is True:  # 마지막 에피소드에서는 애니메이션을 만들고 저장
                    display_frames_as_gif(frames)
                    break
                
                if complete_episodes >= 10: # 10 에피소드 연속으로 성공한 경우
                    print('10 에피소드 연속 성공')
                    is_episode_final = True  # 다음 에피소드가 마지막 에피소드가 됨

# %%
# main
cartpole_env = Environment()
cartpole_env.run()
# Out:
# 0 Episode: Finished after 9 times steps
# 1 Episode: Finished after 21 times steps
# 2 Episode: Finished after 16 times steps
# 3 Episode: Finished after 18 times steps
# 4 Episode: Finished after 12 times steps
# 5 Episode: Finished after 29 times steps
# 6 Episode: Finished after 20 times steps
# 7 Episode: Finished after 8 times steps
# 8 Episode: Finished after 26 times steps
# 9 Episode: Finished after 43 times steps
# 10 Episode: Finished after 13 times steps
# 11 Episode: Finished after 38 times steps
# 12 Episode: Finished after 22 times steps
# 13 Episode: Finished after 26 times steps
# 14 Episode: Finished after 16 times steps
# 15 Episode: Finished after 15 times steps
# 16 Episode: Finished after 30 times steps
# 17 Episode: Finished after 10 times steps
# 18 Episode: Finished after 11 times steps
# 19 Episode: Finished after 20 times steps
# 20 Episode: Finished after 20 times steps
# 21 Episode: Finished after 10 times steps
# 22 Episode: Finished after 15 times steps
# 23 Episode: Finished after 12 times steps
# 24 Episode: Finished after 25 times steps
# 25 Episode: Finished after 10 times steps
# 26 Episode: Finished after 10 times steps
# 27 Episode: Finished after 29 times steps
# 28 Episode: Finished after 62 times steps
# 29 Episode: Finished after 39 times steps
# 30 Episode: Finished after 44 times steps
# 31 Episode: Finished after 24 times steps
# 32 Episode: Finished after 9 times steps
# 33 Episode: Finished after 28 times steps
# 34 Episode: Finished after 10 times steps
# 35 Episode: Finished after 21 times steps
# 36 Episode: Finished after 10 times steps
# 37 Episode: Finished after 44 times steps
# 38 Episode: Finished after 36 times steps
# 39 Episode: Finished after 10 times steps
# 40 Episode: Finished after 15 times steps
# 41 Episode: Finished after 141 times steps
# 42 Episode: Finished after 38 times steps
# 43 Episode: Finished after 27 times steps
# 44 Episode: Finished after 63 times steps
# 45 Episode: Finished after 38 times steps
# 46 Episode: Finished after 19 times steps
# 47 Episode: Finished after 17 times steps
# 48 Episode: Finished after 8 times steps
# 49 Episode: Finished after 51 times steps
# 50 Episode: Finished after 31 times steps
# 51 Episode: Finished after 35 times steps
# 52 Episode: Finished after 137 times steps
# 53 Episode: Finished after 107 times steps
# 54 Episode: Finished after 142 times steps
# 55 Episode: Finished after 87 times steps
# 56 Episode: Finished after 11 times steps
# 57 Episode: Finished after 9 times steps
# 58 Episode: Finished after 10 times steps
# 59 Episode: Finished after 9 times steps
# 61 Episode: Finished after 42 times steps
# 62 Episode: Finished after 189 times steps
# 63 Episode: Finished after 29 times steps
# 64 Episode: Finished after 175 times steps
# 65 Episode: Finished after 102 times steps
# 66 Episode: Finished after 86 times steps
# 67 Episode: Finished after 10 times steps
# 68 Episode: Finished after 44 times steps
# 69 Episode: Finished after 42 times steps
# 70 Episode: Finished after 17 times steps
# 71 Episode: Finished after 161 times steps
# 72 Episode: Finished after 46 times steps
# 73 Episode: Finished after 143 times steps
# 74 Episode: Finished after 169 times steps
# 79 Episode: Finished after 70 times steps
# 80 Episode: Finished after 26 times steps
# 81 Episode: Finished after 10 times steps
# 83 Episode: Finished after 126 times steps
# 84 Episode: Finished after 52 times steps
# 85 Episode: Finished after 43 times steps
# 87 Episode: Finished after 189 times steps
# 88 Episode: Finished after 123 times steps
# 89 Episode: Finished after 50 times steps
# 90 Episode: Finished after 43 times steps
# 91 Episode: Finished after 155 times steps
# 92 Episode: Finished after 83 times steps
# 93 Episode: Finished after 57 times steps
# 94 Episode: Finished after 135 times steps
# 95 Episode: Finished after 160 times steps
# 96 Episode: Finished after 77 times steps
# 97 Episode: Finished after 115 times steps
# 98 Episode: Finished after 164 times steps
# 99 Episode: Finished after 154 times steps
# 100 Episode: Finished after 141 times steps
# 101 Episode: Finished after 66 times steps
# 102 Episode: Finished after 65 times steps
# 103 Episode: Finished after 196 times steps
# 104 Episode: Finished after 175 times steps
# 105 Episode: Finished after 158 times steps
# 106 Episode: Finished after 72 times steps
# 107 Episode: Finished after 74 times steps
# 108 Episode: Finished after 147 times steps
# 109 Episode: Finished after 156 times steps
# 110 Episode: Finished after 133 times steps
# 111 Episode: Finished after 148 times steps
# 112 Episode: Finished after 171 times steps
# 113 Episode: Finished after 130 times steps
# 114 Episode: Finished after 189 times steps
# 118 Episode: Finished after 154 times steps
# 119 Episode: Finished after 117 times steps
# 122 Episode: Finished after 24 times steps
# 123 Episode: Finished after 16 times steps
# 127 Episode: Finished after 176 times steps
# 128 Episode: Finished after 63 times steps
# 130 Episode: Finished after 72 times steps
# 134 Episode: Finished after 167 times steps
# 135 Episode: Finished after 113 times steps
# 140 Episode: Finished after 195 times steps
# 143 Episode: Finished after 26 times steps
# 145 Episode: Finished after 156 times steps
# 146 Episode: Finished after 165 times steps
# 147 Episode: Finished after 71 times steps
# 148 Episode: Finished after 156 times steps
# 149 Episode: Finished after 171 times steps
# 152 Episode: Finished after 183 times steps
# 158 Episode: Finished after 189 times steps
# 159 Episode: Finished after 158 times steps
# 160 Episode: Finished after 85 times steps
# 161 Episode: Finished after 90 times steps
# 163 Episode: Finished after 142 times steps
# 164 Episode: Finished after 147 times steps
# 165 Episode: Finished after 191 times steps
# 168 Episode: Finished after 160 times steps
# 170 Episode: Finished after 179 times steps
# 171 Episode: Finished after 125 times steps
# 173 Episode: Finished after 139 times steps
# 174 Episode: Finished after 156 times steps
# 175 Episode: Finished after 141 times steps
# 176 Episode: Finished after 143 times steps
# 177 Episode: Finished after 189 times steps
# 178 Episode: Finished after 197 times steps
# 179 Episode: Finished after 152 times steps
# 180 Episode: Finished after 186 times steps
# 181 Episode: Finished after 173 times steps
# 188 Episode: Finished after 161 times steps
# 192 Episode: Finished after 166 times steps
# 193 Episode: Finished after 177 times steps
# 194 Episode: Finished after 137 times steps
# 198 Episode: Finished after 125 times steps
# 199 Episode: Finished after 200 times steps
# 200 Episode: Finished after 31 times steps
# 201 Episode: Finished after 165 times steps
# 202 Episode: Finished after 9 times steps
# 204 Episode: Finished after 104 times steps
# 206 Episode: Finished after 142 times steps
# 207 Episode: Finished after 194 times steps
# 208 Episode: Finished after 25 times steps
# 209 Episode: Finished after 116 times steps
# 210 Episode: Finished after 118 times steps
# 211 Episode: Finished after 197 times steps
# 212 Episode: Finished after 64 times steps
# 213 Episode: Finished after 146 times steps
# 214 Episode: Finished after 169 times steps
# 215 Episode: Finished after 159 times steps
# 216 Episode: Finished after 72 times steps
# 217 Episode: Finished after 42 times steps
# 218 Episode: Finished after 178 times steps
# 219 Episode: Finished after 154 times steps
# 221 Episode: Finished after 46 times steps
# 222 Episode: Finished after 146 times steps
# 223 Episode: Finished after 109 times steps
# 224 Episode: Finished after 95 times steps
# 225 Episode: Finished after 189 times steps
# 226 Episode: Finished after 44 times steps
# 227 Episode: Finished after 97 times steps
# 228 Episode: Finished after 169 times steps
# 230 Episode: Finished after 168 times steps
# 231 Episode: Finished after 167 times steps
# 232 Episode: Finished after 148 times steps
# 233 Episode: Finished after 153 times steps
# 234 Episode: Finished after 176 times steps
# 236 Episode: Finished after 155 times steps
# 237 Episode: Finished after 79 times steps
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 3
#       1 # main
#       2 cartpole_env = Environment()
# ----> 3 cartpole_env.run()
#
# Cell In[34], line 28, in Environment.run(self)
#      25 action = self.agent.get_action(observation, episode)
#      27 # 행동 a_t를 실행하여 s_{t+1}, r_{t+1}을 계산
# ---> 28 observation_next, _, terminated, _, _ = self.env.step(action) # reward, info는 사용하지 않으므로 _로 처리함
#      30 # 보상을 부여
#      31 if terminated: # 200단계를 넘어서거나 일정 각도 이상 기울면 terminated 의 값이 True가 됨
#
# File C:\study-pytorch-drl\venv\lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File C:\study-pytorch-drl\venv\lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File C:\study-pytorch-drl\venv\lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File C:\study-pytorch-drl\venv\lib\site-packages\gymnasium\envs\classic_control\cartpole.py:190, in CartPoleEnv.step(self, action)
#     187     reward = 0.0
#     189 if self.render_mode == "human":
# --> 190     self.render()
#     191 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File C:\study-pytorch-drl\venv\lib\site-packages\gymnasium\envs\classic_control\cartpole.py:302, in CartPoleEnv.render(self)
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
# --> 302     self.clock.tick(self.metadata["render_fps"])
#     303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
